# %% [markdown]
# # Coherent Tune

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
booster_turns = [2,4,6,8,10,11,14]
for turns in booster_turns:
    print("Turns: ",turns)
    AB = np.load(r'summerIntern\\coherent_tune_shift\\'+str(turns)+r'turns000_tune.npy',allow_pickle=True)
    print(AB[3])
    plt.plot(AB[1],AB[2])
    plt.show()
# Out:
# Turns:  2
# 0.463
# Turns:  4
# 0.46340000000000003
# Turns:  6
# 0.46230000000000004
# Turns:  8
# 0.4616
# Turns:  10
# 0.4616
# Turns:  11
# 0.4607
# Turns:  14
# 0.4611
